# %%
import pandas as pd
report = '/home/quanpn3/Documents/My_project/UI-Voyager/eval_results/UI-Voyager/logs/20260403105821/detailed_results.csv'
df = pd.read_csv(report)

# %%
df.head(10)
# Out:
#                           task_template  num_complete_trials  \
# 0              AudioRecorderRecordAudio                    0
# 1  AudioRecorderRecordAudioWithFileName                    1
# 2                           BrowserDraw                    1
# 3                           BrowserMaze                    1
# 4                       BrowserMultiply                    1
# 5                       CameraTakePhoto                    1
# 6                       CameraTakeVideo                    1
# 7            ClockStopWatchPausedVerify                    1
# 8                 ClockStopWatchRunning                    1
# 9                       ClockTimerEntry                    1
#
#    mean_success_rate  mean_episode_length  total_runtime_s  num_fail_trials  \
# 0                NaN                  NaN              0.6                1
# 1                0.0                 20.0            115.2                0
# ...

# %%
# !ls eval_results/UI-Voyager/logs/20260403105821/detailed_results.csv
# Out:
# eval_results/UI-Voyager/logs/20260403105821/detailed_results.csv

# %%
df.head(50)
# Out:
#                            task_template  num_complete_trials  \
# 0               AudioRecorderRecordAudio                    0
# 1   AudioRecorderRecordAudioWithFileName                    1
# 2                            BrowserDraw                    1
# 3                            BrowserMaze                    1
# 4                        BrowserMultiply                    1
# 5                        CameraTakePhoto                    1
# 6                        CameraTakeVideo                    1
# 7             ClockStopWatchPausedVerify                    1
# 8                  ClockStopWatchRunning                    1
# 9                        ClockTimerEntry                    1
# 10                    ContactsAddContact                    1
# 11               ContactsNewContactDraft                    1
# 12                    ExpenseAddMultiple                    0
# 13         ExpenseAddMultipleFromGallery                    0
# ...

# %%
df.iloc[50:100,]
# Out:
#                                         task_template  num_complete_trials  \
# 50                       RecipeDeleteDuplicateRecipes                    0
# 51                      RecipeDeleteDuplicateRecipes2                    0
# 52                      RecipeDeleteDuplicateRecipes3                    0
# 53                        RecipeDeleteMultipleRecipes                    0
# 54          RecipeDeleteMultipleRecipesWithConstraint                    0
# 55               RecipeDeleteMultipleRecipesWithNoise                    0
# 56                           RecipeDeleteSingleRecipe                    0
# 57              RecipeDeleteSingleWithRecipeWithNoise                    0
# 58                                RetroCreatePlaylist                    0
# 59                                  RetroPlayingQueue                    0
# 60                              RetroPlaylistDuration                    0
# ...

# %%
df.iloc[100:116, :]
# Out:
#                        task_template  num_complete_trials  mean_success_rate  \
# 100        SystemBrightnessMinVerify                    1                1.0
# 101            SystemCopyToClipboard                    0                NaN
# 102                SystemWifiTurnOff                    1                1.0
# 103          SystemWifiTurnOffVerify                    1                1.0
# 104                 SystemWifiTurnOn                    1                1.0
# 105           SystemWifiTurnOnVerify                    1                1.0
# 106       TasksCompletedTasksForDate                    0                NaN
# 107                 TasksDueNextWeek                    0                NaN
# 108                   TasksDueOnDate                    0                NaN
# 109           TasksHighPriorityTasks                    0                NaN
# 110  TasksHighPriorityTasksDueOnDate                    0                NaN
# ...
